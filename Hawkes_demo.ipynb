# %%
mu = 1; alpha = 1; beta = 7;
x = simulate(20, mu, alpha, beta)
pp_plot(x, mu, alpha, beta)

# %%
x = simulate(1000, mu, alpha, beta)
mle(x, beta)
# Out:
# (1.1499889718913385, 0.9704862033221473)
