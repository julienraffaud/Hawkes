# %% [markdown]
# MLE:

# %%
mu =1; alpha =1; beta = 7;
x = simulate(1000, mu, alpha, beta)
mle(x)
# Out:
# (0.984119840743481, 1.0649639469755605, 7.161291674271618)

# %% [markdown]
# Simulation:

# %%
x = simulate(10, mu, alpha, beta)
pp_plot(x, mu, alpha, beta)
